# %% [markdown]
# <a href="https://colab.research.google.com/github/aishakhalid614-code/TestProj/blob/main/add.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10
b = 2
print(a + b)
# Out:
# 12
